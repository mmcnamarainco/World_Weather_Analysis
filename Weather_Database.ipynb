# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# #1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# #2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# #3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import pandas               as pd
import matplotlib.pyplot    as plt
import numpy                as np

# Import the time library and the datetime module from the datetime library 
import time

# Import the requests library
import requests

# Import the OpenWeatherMap's API key
# Import the datetime module from the datetime library
from config     import weather_api_key
from datetime   import datetime
from citipy     import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.
#
# HEY, IM GUESSING YOU WANT THE COUNTRY IN THERE TOO, SINCE YOU ASK FOR IT LATER?

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_cond = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng, 
                          "Country": city_country,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Conditions": city_cond,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | vardo
# Processing Record 3 of Set 1 | erzin
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | teeli
# Processing Record 8 of Set 1 | lompoc
# Processing Record 9 of Set 1 | kananga
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 12 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 13 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 1 | saint george
# Processing Record 15 of Set 1 | tokur
# Processing Record 16 of Set 1 | komsomolskiy
# Processing Record 17 of Set 1 | cizre
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | tessalit
# Processing Record 20 of Set 1 | sur
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | husavik
# Processing Record 23 of Set 1 | eldorado
# Processing Record 24 of Set 1 | riberalta
# Processing Record 25 of Set 1 | khani
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | cairo
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | salalah
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | dogondoutchi
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | ixtapa
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | muros
# Processing Record 41 of Set 1 | mount isa
# Processing Record 42 of Set 1 | buala
# Processing Record 43 of Set 1 | churapcha
# Processing Record 44 of Set 1 | abbeville
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | leshukonskoye
# Processing Record 47 of Set 1 | sitka
# Processing Record 48 of Set 1 | sao filipe
# Processing Record 49 of Set 1 | olafsvik
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | lagoa
# Processing Record 2 of Set 2 | tupik
# Processing Record 3 of Set 2 | pangnirtung
# Processing Record 4 of Set 2 | belousovka
# Processing Record 5 of Set 2 | belaya gora
# Processing Record 6 of Set 2 | espanola
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | shizunai
# Processing Record 9 of Set 2 | samarai
# Processing Record 10 of Set 2 | manzanillo
# Processing Record 11 of Set 2 | peleduy
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | severo-kurilsk
# Processing Record 17 of Set 2 | atbasar
# Processing Record 18 of Set 2 | tura
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | ahipara
# Processing Record 21 of Set 2 | mogoytuy
# Processing Record 22 of Set 2 | vostok
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | marystown
# Processing Record 25 of Set 2 | grenfell
# Processing Record 26 of Set 2 | yelizovo
# Processing Record 27 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 2 | evensk
# Processing Record 29 of Set 2 | ponta do sol
# Processing Record 30 of Set 2 | luderitz
# Processing Record 31 of Set 2 | vila velha
# Processing Record 32 of Set 2 | ambon
# Processing Record 33 of Set 2 | thompson
# Processing Record 34 of Set 2 | thinadhoo
# Processing Record 35 of Set 2 | leningradskiy
# Processing Record 36 of Set 2 | geraldton
# Processing Record 37 of Set 2 | acapulco
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | salta
# Processing Record 40 of Set 2 | babu
# Processing Record 41 of Set 2 | paamiut
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | bon air
# Processing Record 47 of Set 2 | aklavik
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | elko
# Processing Record 50 of Set 2 | saint-louis
# Processing Record 1 of Set 3 | mocuba
# Processing Record 2 of Set 3 | sao joao da barra
# Processing Record 3 of Set 3 | bathsheba
# Processing Record 4 of Set 3 | half moon bay
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | pangody
# Processing Record 7 of Set 3 | kirakira
# Processing Record 8 of Set 3 | esil
# Processing Record 9 of Set 3 | mayumba
# Processing Record 10 of Set 3 | hami
# Processing Record 11 of Set 3 | cabo san lucas
# Processing Record 12 of Set 3 | wuda
# Processing Record 13 of Set 3 | la ronge
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 3 | naron
# Processing Record 16 of Set 3 | sahrak
# City not found. Skipping...
# Processing Record 17 of Set 3 | merauke
# Processing Record 18 of Set 3 | tigil
# Processing Record 19 of Set 3 | souillac
# Processing Record 20 of Set 3 | bluff
# Processing Record 21 of Set 3 | cherskiy
# Processing Record 22 of Set 3 | faya
# Processing Record 23 of Set 3 | ust-nera
# Processing Record 24 of Set 3 | mtwara
# Processing Record 25 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 3 | honningsvag
# Processing Record 27 of Set 3 | rawson
# Processing Record 28 of Set 3 | hasaki
# Processing Record 29 of Set 3 | westport
# Processing Record 30 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 3 | puerto del rosario
# Processing Record 32 of Set 3 | lebu
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 3 | svetlyy
# Processing Record 36 of Set 3 | pevek
# Processing Record 37 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 3 | colesberg
# Processing Record 39 of Set 3 | dawei
# Processing Record 40 of Set 3 | wahiawa
# Processing Record 41 of Set 3 | chuy
# Processing Record 42 of Set 3 | caravelas
# Processing Record 43 of Set 3 | mitu
# Processing Record 44 of Set 3 | tombouctou
# Processing Record 45 of Set 3 | poronaysk
# Processing Record 46 of Set 3 | villanueva
# Processing Record 47 of Set 3 | the valley
# Processing Record 48 of Set 3 | nuuk
# Processing Record 49 of Set 3 | ponta delgada
# Processing Record 50 of Set 3 | namikupa
# Processing Record 1 of Set 4 | airai
# Processing Record 2 of Set 4 | emerald
# Processing Record 3 of Set 4 | acari
# Processing Record 4 of Set 4 | port lincoln
# Processing Record 5 of Set 4 | pavilosta
# Processing Record 6 of Set 4 | nishihara
# Processing Record 7 of Set 4 | san cristobal
# Processing Record 8 of Set 4 | novyy starodub
# Processing Record 9 of Set 4 | norman wells
# Processing Record 10 of Set 4 | clarksburg
# Processing Record 11 of Set 4 | hofn
# Processing Record 12 of Set 4 | mujiayingzi
# Processing Record 13 of Set 4 | fortuna
# Processing Record 14 of Set 4 | northam
# Processing Record 15 of Set 4 | qaanaaq
# Processing Record 16 of Set 4 | riyadh
# Processing Record 17 of Set 4 | inhambane
# Processing Record 18 of Set 4 | eyl
# Processing Record 19 of Set 4 | sibolga
# Processing Record 20 of Set 4 | saldanha
# Processing Record 21 of Set 4 | tiksi
# Processing Record 22 of Set 4 | vila
# Processing Record 23 of Set 4 | guhagar
# Processing Record 24 of Set 4 | lorengau
# Processing Record 25 of Set 4 | berdigestyakh
# Processing Record 26 of Set 4 | ukiah
# Processing Record 27 of Set 4 | nemuro
# Processing Record 28 of Set 4 | college
# Processing Record 29 of Set 4 | torbay
# Processing Record 30 of Set 4 | ilulissat
# Processing Record 31 of Set 4 | blonduos
# City not found. Skipping...
# Processing Record 32 of Set 4 | new norfolk
# Processing Record 33 of Set 4 | cameta
# Processing Record 34 of Set 4 | dukat
# Processing Record 35 of Set 4 | grand gaube
# Processing Record 36 of Set 4 | coihaique
# Processing Record 37 of Set 4 | los llanos de aridane
# Processing Record 38 of Set 4 | port pirie
# Processing Record 39 of Set 4 | bara
# Processing Record 40 of Set 4 | yerbogachen
# Processing Record 41 of Set 4 | castro
# Processing Record 42 of Set 4 | baoning
# Processing Record 43 of Set 4 | deputatskiy
# Processing Record 44 of Set 4 | saskylakh
# Processing Record 45 of Set 4 | poum
# Processing Record 46 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 4 | southbridge
# Processing Record 48 of Set 4 | kuching
# Processing Record 49 of Set 4 | yellowknife
# Processing Record 50 of Set 4 | gimli
# Processing Record 1 of Set 5 | port hardy
# Processing Record 2 of Set 5 | saryg-sep
# Processing Record 3 of Set 5 | whitianga
# Processing Record 4 of Set 5 | hilo
# Processing Record 5 of Set 5 | dudinka
# Processing Record 6 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 5 | guerrero negro
# Processing Record 8 of Set 5 | alugan
# Processing Record 9 of Set 5 | oriximina
# Processing Record 10 of Set 5 | padang
# Processing Record 11 of Set 5 | butaritari
# Processing Record 12 of Set 5 | esperance
# Processing Record 13 of Set 5 | totness
# Processing Record 14 of Set 5 | broken hill
# Processing Record 15 of Set 5 | beringovskiy
# Processing Record 16 of Set 5 | kaeo
# Processing Record 17 of Set 5 | east london
# Processing Record 18 of Set 5 | belyy yar
# Processing Record 19 of Set 5 | kudahuvadhoo
# Processing Record 20 of Set 5 | mahebourg
# Processing Record 21 of Set 5 | teguldet
# Processing Record 22 of Set 5 | tezu
# Processing Record 23 of Set 5 | iralaya
# Processing Record 24 of Set 5 | hambantota
# Processing Record 25 of Set 5 | nouadhibou
# Processing Record 26 of Set 5 | longyearbyen
# Processing Record 27 of Set 5 | morros
# Processing Record 28 of Set 5 | jericho
# Processing Record 29 of Set 5 | nikolskoye
# Processing Record 30 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 5 | bambous virieux
# Processing Record 32 of Set 5 | yenagoa
# Processing Record 33 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 5 | oranjemund
# Processing Record 35 of Set 5 | jalu
# Processing Record 36 of Set 5 | uyuni
# Processing Record 37 of Set 5 | nakanojo
# Processing Record 38 of Set 5 | katha
# City not found. Skipping...
# Processing Record 39 of Set 5 | ihosy
# Processing Record 40 of Set 5 | manama
# Processing Record 41 of Set 5 | krasnokamensk
# Processing Record 42 of Set 5 | kavieng
# Processing Record 43 of Set 5 | wanning
# Processing Record 44 of Set 5 | ayan
# Processing Record 45 of Set 5 | basco
# Processing Record 46 of Set 5 | diffa
# Processing Record 47 of Set 5 | provideniya
# Processing Record 48 of Set 5 | mandalgovi
# Processing Record 49 of Set 5 | luanda
# Processing Record 50 of Set 5 | maralal
# Processing Record 1 of Set 6 | hoquiam
# Processing Record 2 of Set 6 | skjaerhollen
# City not found. Skipping...
# Processing Record 3 of Set 6 | nazilli
# Processing Record 4 of Set 6 | tuy hoa
# Processing Record 5 of Set 6 | roma
# Processing Record 6 of Set 6 | yumen
# Processing Record 7 of Set 6 | clyde river
# Processing Record 8 of Set 6 | banjarmasin
# Processing Record 9 of Set 6 | buri
# Processing Record 10 of Set 6 | talnakh
# Processing Record 11 of Set 6 | roald
# Processing Record 12 of Set 6 | cayenne
# Processing Record 13 of Set 6 | tilichiki
# Processing Record 14 of Set 6 | watsa
# Processing Record 15 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 6 | noumea
# Processing Record 17 of Set 6 | gisborne
# Processing Record 18 of Set 6 | dolna mitropolija
# City not found. Skipping...
# Processing Record 19 of Set 6 | dingle
# Processing Record 20 of Set 6 | lethem
# Processing Record 21 of Set 6 | temiscaming
# Processing Record 22 of Set 6 | mehamn
# Processing Record 23 of Set 6 | bethel
# Processing Record 24 of Set 6 | mvuma
# Processing Record 25 of Set 6 | hithadhoo
# Processing Record 26 of Set 6 | tasiilaq
# Processing Record 27 of Set 6 | codrington
# Processing Record 28 of Set 6 | kirkland lake
# Processing Record 29 of Set 6 | victoria
# Processing Record 30 of Set 6 | yulara
# Processing Record 31 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 6 | santa maria
# Processing Record 33 of Set 6 | thunder bay
# Processing Record 34 of Set 6 | hualmay
# Processing Record 35 of Set 6 | krivopolyanye
# City not found. Skipping...
# Processing Record 36 of Set 6 | vagur
# Processing Record 37 of Set 6 | turukhansk
# Processing Record 38 of Set 6 | ribeira grande
# Processing Record 39 of Set 6 | key west
# Processing Record 40 of Set 6 | kaitangata
# Processing Record 41 of Set 6 | albanel
# Processing Record 42 of Set 6 | narsaq
# Processing Record 43 of Set 6 | huittinen
# Processing Record 44 of Set 6 | vendas novas
# Processing Record 45 of Set 6 | fort nelson
# Processing Record 46 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 47 of Set 6 | andenes
# Processing Record 48 of Set 6 | kushnarenkovo
# Processing Record 49 of Set 6 | tutoia
# Processing Record 50 of Set 6 | banda aceh
# Processing Record 1 of Set 7 | nanchang
# Processing Record 2 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 7 | ouadda
# Processing Record 4 of Set 7 | jacareacanga
# Processing Record 5 of Set 7 | cap malheureux
# Processing Record 6 of Set 7 | kadaya
# Processing Record 7 of Set 7 | asau
# Processing Record 8 of Set 7 | alice springs
# Processing Record 9 of Set 7 | portland
# Processing Record 10 of Set 7 | kingsville
# Processing Record 11 of Set 7 | naze
# Processing Record 12 of Set 7 | srednekolymsk
# Processing Record 13 of Set 7 | alta floresta
# Processing Record 14 of Set 7 | lata
# Processing Record 15 of Set 7 | mount gambier
# Processing Record 16 of Set 7 | sivas
# Processing Record 17 of Set 7 | santa marinella
# Processing Record 18 of Set 7 | karratha
# Processing Record 19 of Set 7 | san quintin
# Processing Record 20 of Set 7 | lumberton
# Processing Record 21 of Set 7 | san ignacio
# Processing Record 22 of Set 7 | moerai
# Processing Record 23 of Set 7 | panacan
# Processing Record 24 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 25 of Set 7 | kahului
# Processing Record 26 of Set 7 | nanortalik
# Processing Record 27 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 7 | amot
# Processing Record 29 of Set 7 | moussoro
# Processing Record 30 of Set 7 | malakwal
# Processing Record 31 of Set 7 | oberndorf
# Processing Record 32 of Set 7 | katsuura
# Processing Record 33 of Set 7 | sakakah
# Processing Record 34 of Set 7 | touros
# Processing Record 35 of Set 7 | jieshi
# Processing Record 36 of Set 7 | san anselmo
# Processing Record 37 of Set 7 | aksu
# Processing Record 38 of Set 7 | jimani
# Processing Record 39 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 40 of Set 7 | hamilton
# Processing Record 41 of Set 7 | pindiga
# Processing Record 42 of Set 7 | nyrob
# Processing Record 43 of Set 7 | pahrump
# Processing Record 44 of Set 7 | gizo
# Processing Record 45 of Set 7 | jawhar
# Processing Record 46 of Set 7 | fukue
# Processing Record 47 of Set 7 | qarqin
# Processing Record 48 of Set 7 | takoradi
# Processing Record 49 of Set 7 | muroto
# Processing Record 50 of Set 7 | namatanai
# Processing Record 1 of Set 8 | impfondo
# Processing Record 2 of Set 8 | brigantine
# Processing Record 3 of Set 8 | menongue
# Processing Record 4 of Set 8 | biltine
# Processing Record 5 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 6 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 8 | rafiganj
# Processing Record 8 of Set 8 | nanning
# Processing Record 9 of Set 8 | phan thiet
# Processing Record 10 of Set 8 | batagay
# Processing Record 11 of Set 8 | dzaoudzi
# Processing Record 12 of Set 8 | teya
# Processing Record 13 of Set 8 | tall kayf
# Processing Record 14 of Set 8 | uige
# Processing Record 15 of Set 8 | kavaratti
# Processing Record 16 of Set 8 | biograd na moru
# Processing Record 17 of Set 8 | barao de melgaco
# Processing Record 18 of Set 8 | skjervoy
# Processing Record 19 of Set 8 | faanui
# Processing Record 20 of Set 8 | sioux lookout
# Processing Record 21 of Set 8 | granadilla de abona
# Processing Record 22 of Set 8 | ancud
# Processing Record 23 of Set 8 | jerusalem
# Processing Record 24 of Set 8 | flinders
# Processing Record 25 of Set 8 | namibe
# Processing Record 26 of Set 8 | kothi
# Processing Record 27 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 8 | ouesso
# Processing Record 29 of Set 8 | san policarpo
# Processing Record 30 of Set 8 | astana
# Processing Record 31 of Set 8 | vyartsilya
# Processing Record 32 of Set 8 | kutum
# Processing Record 33 of Set 8 | abay
# Processing Record 34 of Set 8 | sao joaquim
# Processing Record 35 of Set 8 | san jeronimo
# Processing Record 36 of Set 8 | bredy
# Processing Record 37 of Set 8 | arlit
# Processing Record 38 of Set 8 | uribia
# Processing Record 39 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 8 | kruisfontein
# Processing Record 41 of Set 8 | balagansk
# Processing Record 42 of Set 8 | chipinge
# Processing Record 43 of Set 8 | egvekinot
# Processing Record 44 of Set 8 | charters towers
# Processing Record 45 of Set 8 | matay
# Processing Record 46 of Set 8 | lang suan
# Processing Record 47 of Set 8 | iqaluit
# Processing Record 48 of Set 8 | boyolangu
# Processing Record 49 of Set 8 | vilyuysk
# Processing Record 50 of Set 8 | martapura
# Processing Record 1 of Set 9 | springdale
# Processing Record 2 of Set 9 | bengkulu
# Processing Record 3 of Set 9 | coruripe
# Processing Record 4 of Set 9 | smoky lake
# Processing Record 5 of Set 9 | jati
# Processing Record 6 of Set 9 | belmonte
# Processing Record 7 of Set 9 | kilindoni
# Processing Record 8 of Set 9 | brae
# Processing Record 9 of Set 9 | petropavl
# Processing Record 10 of Set 9 | leh
# Processing Record 11 of Set 9 | bilibino
# Processing Record 12 of Set 9 | sesheke
# Processing Record 13 of Set 9 | kenora
# Processing Record 14 of Set 9 | tallahassee
# Processing Record 15 of Set 9 | nome
# Processing Record 16 of Set 9 | upernavik
# Processing Record 17 of Set 9 | bougouni
# Processing Record 18 of Set 9 | bukama
# Processing Record 19 of Set 9 | kitob
# Processing Record 20 of Set 9 | ostersund
# Processing Record 21 of Set 9 | antalya
# Processing Record 22 of Set 9 | hervey bay
# Processing Record 23 of Set 9 | alofi
# Processing Record 24 of Set 9 | mae hong son
# Processing Record 25 of Set 9 | lalawigan
# Processing Record 26 of Set 9 | jambi
# Processing Record 27 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 9 | pingshan
# Processing Record 29 of Set 9 | severo-yeniseyskiy
# Processing Record 30 of Set 9 | vondrozo
# Processing Record 31 of Set 9 | liverpool
# Processing Record 32 of Set 9 | maryborough
# Processing Record 33 of Set 9 | palaikastron
# Processing Record 34 of Set 9 | zhigansk
# Processing Record 35 of Set 9 | tsaratanana
# Processing Record 36 of Set 9 | talmenka
# Processing Record 37 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 9 | okha
# Processing Record 39 of Set 9 | bundibugyo
# Processing Record 40 of Set 9 | kondinskoye
# Processing Record 41 of Set 9 | san patricio
# Processing Record 42 of Set 9 | okhotsk
# Processing Record 43 of Set 9 | mazamari
# Processing Record 44 of Set 9 | ipixuna
# Processing Record 45 of Set 9 | damghan
# Processing Record 46 of Set 9 | bradford
# Processing Record 47 of Set 9 | palasa
# Processing Record 48 of Set 9 | jieshou
# Processing Record 49 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 9 | sao felix do xingu
# Processing Record 1 of Set 10 | ampanihy
# Processing Record 2 of Set 10 | victor harbor
# Processing Record 3 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 4 of Set 10 | diego de almagro
# Processing Record 5 of Set 10 | humaita
# Processing Record 6 of Set 10 | guarapari
# Processing Record 7 of Set 10 | santa barbara
# Processing Record 8 of Set 10 | port augusta
# Processing Record 9 of Set 10 | buloh kasap
# Processing Record 10 of Set 10 | ferme-neuve
# Processing Record 11 of Set 10 | meiktila
# Processing Record 12 of Set 10 | ust-karsk
# Processing Record 13 of Set 10 | makakilo city
# Processing Record 14 of Set 10 | peniche
# Processing Record 15 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 16 of Set 10 | altay
# Processing Record 17 of Set 10 | antofagasta
# Processing Record 18 of Set 10 | xingyi
# Processing Record 19 of Set 10 | albert
# Processing Record 20 of Set 10 | kungurtug
# Processing Record 21 of Set 10 | chicama
# Processing Record 22 of Set 10 | kloulklubed
# Processing Record 23 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 24 of Set 10 | komyshnya
# Processing Record 25 of Set 10 | soe
# Processing Record 26 of Set 10 | kissimmee
# Processing Record 27 of Set 10 | pringsewu
# Processing Record 28 of Set 10 | knysna
# Processing Record 29 of Set 10 | klaksvik
# Processing Record 30 of Set 10 | atambua
# Processing Record 31 of Set 10 | baykit
# Processing Record 32 of Set 10 | ulagan
# Processing Record 33 of Set 10 | rocha
# Processing Record 34 of Set 10 | wilmington
# Processing Record 35 of Set 10 | tautira
# Processing Record 36 of Set 10 | goroka
# Processing Record 37 of Set 10 | sadovoye
# Processing Record 38 of Set 10 | kamenka
# Processing Record 39 of Set 10 | port hawkesbury
# Processing Record 40 of Set 10 | ust-ordynskiy
# Processing Record 41 of Set 10 | najran
# Processing Record 42 of Set 10 | penzance
# Processing Record 43 of Set 10 | dongsheng
# Processing Record 44 of Set 10 | hailar
# Processing Record 45 of Set 10 | bazaliya
# Processing Record 46 of Set 10 | wufeng
# Processing Record 47 of Set 10 | khandyga
# Processing Record 48 of Set 10 | skiros
# City not found. Skipping...
# Processing Record 49 of Set 10 | palana
# Processing Record 50 of Set 10 | santa marta
# Processing Record 1 of Set 11 | nelson bay
# Processing Record 2 of Set 11 | ambilobe
# Processing Record 3 of Set 11 | stornoway
# Processing Record 4 of Set 11 | seoul
# Processing Record 5 of Set 11 | caceres
# Processing Record 6 of Set 11 | guanica
# Processing Record 7 of Set 11 | mbuji-mayi
# Processing Record 8 of Set 11 | port macquarie
# Processing Record 9 of Set 11 | vestmannaeyjar
# Processing Record 10 of Set 11 | high prairie
# Processing Record 11 of Set 11 | rancho palos verdes
# Processing Record 12 of Set 11 | texas city
# Processing Record 13 of Set 11 | lazaro cardenas
# Processing Record 14 of Set 11 | halifax
# Processing Record 15 of Set 11 | lakatoro
# Processing Record 16 of Set 11 | meulaboh
# Processing Record 17 of Set 11 | anloga
# Processing Record 18 of Set 11 | high level
# Processing Record 19 of Set 11 | alegrete
# Processing Record 20 of Set 11 | oudtshoorn
# Processing Record 21 of Set 11 | villamontes
# Processing Record 22 of Set 11 | marawi
# Processing Record 23 of Set 11 | gamba
# Processing Record 24 of Set 11 | tarauaca
# Processing Record 25 of Set 11 | daru
# Processing Record 26 of Set 11 | timizart
# Processing Record 27 of Set 11 | owando
# Processing Record 28 of Set 11 | lavrentiya
# Processing Record 29 of Set 11 | dunedin
# Processing Record 30 of Set 11 | kota kinabalu
# Processing Record 31 of Set 11 | pareora
# Processing Record 32 of Set 11 | thai binh
# Processing Record 33 of Set 11 | soke
# Processing Record 34 of Set 11 | duncan
# Processing Record 35 of Set 11 | coquimbo
# Processing Record 36 of Set 11 | kathu
# Processing Record 37 of Set 11 | auch
# Processing Record 38 of Set 11 | chernyshevskiy
# Processing Record 39 of Set 11 | gouyave
# Processing Record 40 of Set 11 | kununurra
# Processing Record 41 of Set 11 | coxim
# Processing Record 42 of Set 11 | matias olimpio
# Processing Record 43 of Set 11 | shatrovo
# Processing Record 44 of Set 11 | yining
# Processing Record 45 of Set 11 | cidreira
# Processing Record 46 of Set 11 | taoudenni
# Processing Record 47 of Set 11 | quatre cocos
# Processing Record 48 of Set 11 | altos del rosario
# Processing Record 49 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 11 | vila franca do campo
# Processing Record 1 of Set 12 | pouembout
# Processing Record 2 of Set 12 | huancavelica
# Processing Record 3 of Set 12 | ibra
# Processing Record 4 of Set 12 | lichtenburg
# Processing Record 5 of Set 12 | san rafael
# Processing Record 6 of Set 12 | ziyang
# Processing Record 7 of Set 12 | christchurch
# Processing Record 8 of Set 12 | kesinga
# Processing Record 9 of Set 12 | borogontsy
# Processing Record 10 of Set 12 | bandarbeyla
# Processing Record 11 of Set 12 | turayf
# Processing Record 12 of Set 12 | binzhou
# Processing Record 13 of Set 12 | gander
# Processing Record 14 of Set 12 | napier
# Processing Record 15 of Set 12 | ouallam
# Processing Record 16 of Set 12 | kulhudhuffushi
# Processing Record 17 of Set 12 | baiyin
# Processing Record 18 of Set 12 | neiafu
# Processing Record 19 of Set 12 | high rock
# Processing Record 20 of Set 12 | french harbor
# Processing Record 21 of Set 12 | campbeltown
# Processing Record 22 of Set 12 | new milford
# Processing Record 23 of Set 12 | otacilio costa
# Processing Record 24 of Set 12 | quelimane
# Processing Record 25 of Set 12 | pavda
# City not found. Skipping...
# Processing Record 26 of Set 12 | cocorit
# Processing Record 27 of Set 12 | gornopravdinsk
# Processing Record 28 of Set 12 | tamworth
# Processing Record 29 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 12 | rio grande
# Processing Record 31 of Set 12 | punuare
# Processing Record 32 of Set 12 | sirok
# Processing Record 33 of Set 12 | jiangkou
# Processing Record 34 of Set 12 | polunochnoye
# Processing Record 35 of Set 12 | anchorage
# Processing Record 36 of Set 12 | kenai
# Processing Record 37 of Set 12 | kitaibaraki
# Processing Record 38 of Set 12 | lusambo
# Processing Record 39 of Set 12 | portree
# Processing Record 40 of Set 12 | harnosand
# Processing Record 41 of Set 12 | onguday
# Processing Record 42 of Set 12 | goundam
# Processing Record 43 of Set 12 | bollnas
# Processing Record 44 of Set 12 | madang
# Processing Record 45 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 46 of Set 12 | cholet
# Processing Record 47 of Set 12 | jumla
# Processing Record 48 of Set 12 | paciran
# Processing Record 49 of Set 12 | lowestoft
# Processing Record 50 of Set 12 | kuliyapitiya
# Processing Record 1 of Set 13 | betanzos
# Processing Record 2 of Set 13 | constitucion
# Processing Record 3 of Set 13 | alice
# Processing Record 4 of Set 13 | hovd
# Processing Record 5 of Set 13 | te anau
# Processing Record 6 of Set 13 | eirunepe
# Processing Record 7 of Set 13 | san ramon de la nueva oran
# Processing Record 8 of Set 13 | richards bay
# Processing Record 9 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 13 | lazo
# Processing Record 11 of Set 13 | malakal
# Processing Record 12 of Set 13 | molo
# Processing Record 13 of Set 13 | tapes
# Processing Record 14 of Set 13 | west odessa
# Processing Record 15 of Set 13 | aksarka
# Processing Record 16 of Set 13 | kolondieba
# Processing Record 17 of Set 13 | kushiro
# Processing Record 18 of Set 13 | ullapool
# Processing Record 19 of Set 13 | maxingal
# Processing Record 20 of Set 13 | magistralnyy
# Processing Record 21 of Set 13 | castlemaine
# Processing Record 22 of Set 13 | sorland
# Processing Record 23 of Set 13 | hasilpur
# Processing Record 24 of Set 13 | north platte
# Processing Record 25 of Set 13 | natal
# Processing Record 26 of Set 13 | meadow lake
# Processing Record 27 of Set 13 | boa vista
# Processing Record 28 of Set 13 | gazanjyk
# Processing Record 29 of Set 13 | zyryanka
# Processing Record 30 of Set 13 | tabulbah
# City not found. Skipping...
# Processing Record 31 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 13 | aykhal
# Processing Record 33 of Set 13 | sept-iles
# Processing Record 34 of Set 13 | elizabeth city
# Processing Record 35 of Set 13 | mecca
# Processing Record 36 of Set 13 | vanimo
# Processing Record 37 of Set 13 | ekibastuz
# Processing Record 38 of Set 13 | bereda
# Processing Record 39 of Set 13 | ayolas
# Processing Record 40 of Set 13 | maragogi
# Processing Record 41 of Set 13 | ust-kuyga
# Processing Record 42 of Set 13 | biloxi
# Processing Record 43 of Set 13 | tecoanapa
# Processing Record 44 of Set 13 | carutapera
# Processing Record 45 of Set 13 | garhi khairo
# Processing Record 46 of Set 13 | boende
# Processing Record 47 of Set 13 | tyup
# Processing Record 48 of Set 13 | vila do maio
# Processing Record 49 of Set 13 | saint-georges
# Processing Record 50 of Set 13 | sohag
# Processing Record 1 of Set 14 | de land
# Processing Record 2 of Set 14 | tuatapere
# Processing Record 3 of Set 14 | rondonopolis
# Processing Record 4 of Set 14 | ayr
# Processing Record 5 of Set 14 | birjand
# Processing Record 6 of Set 14 | henties bay
# Processing Record 7 of Set 14 | ilheus
# Processing Record 8 of Set 14 | sabha
# Processing Record 9 of Set 14 | alamosa
# Processing Record 10 of Set 14 | jibuti
# Processing Record 11 of Set 14 | antalaha
# Processing Record 12 of Set 14 | sinnamary
# Processing Record 13 of Set 14 | huntington
# Processing Record 14 of Set 14 | ardmore
# Processing Record 15 of Set 14 | kamaishi
# Processing Record 16 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 14 | gibara
# Processing Record 18 of Set 14 | tosya
# Processing Record 19 of Set 14 | margate
# Processing Record 20 of Set 14 | sangmelima
# Processing Record 21 of Set 14 | port-gentil
# Processing Record 22 of Set 14 | phangnga
# Processing Record 23 of Set 14 | bafq
# Processing Record 24 of Set 14 | soyo
# Processing Record 25 of Set 14 | vao
# Processing Record 26 of Set 14 | bonavista
# Processing Record 27 of Set 14 | beterou
# Processing Record 28 of Set 14 | nizhniy odes
# Processing Record 29 of Set 14 | broome
# Processing Record 30 of Set 14 | nykoping
# Processing Record 31 of Set 14 | mahon
# Processing Record 32 of Set 14 | comodoro rivadavia
# Processing Record 33 of Set 14 | ostrovnoy
# Processing Record 34 of Set 14 | kangaatsiaq
# Processing Record 35 of Set 14 | pandan
# Processing Record 36 of Set 14 | las lomas
# Processing Record 37 of Set 14 | mouzakion
# City not found. Skipping...
# Processing Record 38 of Set 14 | magomeni
# Processing Record 39 of Set 14 | ulaangom
# Processing Record 40 of Set 14 | guna
# Processing Record 41 of Set 14 | sabang
# Processing Record 42 of Set 14 | kargasok
# Processing Record 43 of Set 14 | razole
# Processing Record 44 of Set 14 | kalemie
# Processing Record 45 of Set 14 | warri
# Processing Record 46 of Set 14 | mpika
# Processing Record 47 of Set 14 | chumikan
# Processing Record 48 of Set 14 | champasak
# Processing Record 49 of Set 14 | omsukchan
# Processing Record 50 of Set 14 | abu dhabi
# Processing Record 1 of Set 15 | berlevag
# Processing Record 2 of Set 15 | prince rupert
# Processing Record 3 of Set 15 | majalengka
# Processing Record 4 of Set 15 | avera
# Processing Record 5 of Set 15 | nioro
# Processing Record 6 of Set 15 | eenhana
# Processing Record 7 of Set 15 | el alto
# Processing Record 8 of Set 15 | kodinsk
# Processing Record 9 of Set 15 | manggar
# Processing Record 10 of Set 15 | prado
# Processing Record 11 of Set 15 | pochutla
# Processing Record 12 of Set 15 | tibu
# Processing Record 13 of Set 15 | safford
# Processing Record 14 of Set 15 | nynashamn
# Processing Record 15 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 16 of Set 15 | sembakung
# Processing Record 17 of Set 15 | ayame
# Processing Record 18 of Set 15 | monzon
# Processing Record 19 of Set 15 | anadyr
# Processing Record 20 of Set 15 | sochi
# Processing Record 21 of Set 15 | iranshahr
# Processing Record 22 of Set 15 | yaounde
# Processing Record 23 of Set 15 | santa fe
# Processing Record 24 of Set 15 | marondera
# Processing Record 25 of Set 15 | dunyapur
# Processing Record 26 of Set 15 | caetite
# Processing Record 27 of Set 15 | bilma
# Processing Record 28 of Set 15 | moindou
# Processing Record 29 of Set 15 | kushima
# Processing Record 30 of Set 15 | kyra
# Processing Record 31 of Set 15 | abnub
# Processing Record 32 of Set 15 | fethiye
# Processing Record 33 of Set 15 | sechura
# Processing Record 34 of Set 15 | kutoarjo
# Processing Record 35 of Set 15 | solnechnyy
# Processing Record 36 of Set 15 | chapais
# Processing Record 37 of Set 15 | fare
# Processing Record 38 of Set 15 | bratsk
# Processing Record 39 of Set 15 | boueni
# Processing Record 40 of Set 15 | raudeberg
# Processing Record 41 of Set 15 | mongoumba
# Processing Record 42 of Set 15 | veraval
# Processing Record 43 of Set 15 | palauig
# Processing Record 44 of Set 15 | sosenskiy
# Processing Record 45 of Set 15 | kolobovo
# Processing Record 46 of Set 15 | matameye
# City not found. Skipping...
# Processing Record 47 of Set 15 | ahumada
# City not found. Skipping...
# Processing Record 48 of Set 15 | grand-santi
# Processing Record 49 of Set 15 | viedma
# Processing Record 50 of Set 15 | kalmunai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 697

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(5)
# Out:
#           City      Lat       Lng Country  Max Temp  Humidity  Cloudiness  \
# 0      Ushuaia -54.8000  -68.3000      AR     46.06        61          75
# 1        Vardo  70.3705   31.1107      NO     46.38        93          75
# 2        Erzin  36.9559   36.2000      TR     71.71        80           0
# 3  Port Alfred -33.5906   26.8910      ZA     62.67        76         100
# 4       Hobart -42.8794  147.3294      AU     57.06        90          75
#
#    Wind Speed       Conditions                 Date
# 0        4.61    broken clouds  2022-10-06 17:56:27
# 1       28.77    broken clouds  2022-10-06 17:58:12
# 2        1.14        clear sky  2022-10-06 17:58:12
# 3       14.63  overcast clouds  2022-10-06 17:58:13
# 4        6.91    moderate rain  2022-10-06 17:57:10

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Country', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Conditions', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

new_column_order = ['City', 'Country',  'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
       'Wind Speed', 'Conditions']

# %%
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Conditions     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
